# %% [markdown]
# # Data Frame

# %%
import pandas as pd

# %%
import numpy as np

# %%
y=pd.DataFrame(np.arange(24).reshape(6,4),
               columns=['a','b','c','d'],
              index=[1,2,3,4,5,6])
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y.loc[1:2]
# Out:
#    a  b  c  d
# 1  0  1  2  3
# 2  4  5  6  7

# %%
y.iloc[1:2]
# Out:
#    a  b  c  d
# 2  4  5  6  7

# %%
y[['a','b']]
# Out:
#     a   b
# 1   0   1
# 2   4   5
# 3   8   9
# 4  12  13
# 5  16  17
# 6  20  21

# %%
z=pd.DataFrame(np.arange(24).reshape(6,4),
               columns=['a','b','c','d'],
              index=list('abcdef'))
z
# Out:
#     a   b   c   d
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15
# e  16  17  18  19
# f  20  21  22  23

# %%
z[['a','c']]
# Out:
#     a   c
# a   0   2
# b   4   6
# c   8  10
# d  12  14
# e  16  18
# f  20  22

# %%
z.loc['a']
# Out:
# a    0
# b    1
# c    2
# d    3
# Name: a, dtype: int32

# %%
z['a']
# Out:
# a     0
# b     4
# c     8
# d    12
# e    16
# f    20
# Name: a, dtype: int32

# %%
y.a
# Out:
# 1     0
# 2     4
# 3     8
# 4    12
# 5    16
# 6    20
# Name: a, dtype: int32

# %%
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y.iloc[1][0]
# Out:
# 4

# %%
y['a'][1]
# Out:
# 0

# %%
y.T
# Out:
#    1  2   3   4   5   6
# a  0  4   8  12  16  20
# b  1  5   9  13  17  21
# c  2  6  10  14  18  22
# d  3  7  11  15  19  23

# %%
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y=y.T

# %%
y
# Out:
#    1  2   3   4   5   6
# a  0  4   8  12  16  20
# b  1  5   9  13  17  21
# c  2  6  10  14  18  22
# d  3  7  11  15  19  23

# %%
y=y.T

# %%
y
# Out:
#     a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15
# 5  16  17  18  19
# 6  20  21  22  23

# %%
y['e']=y['a']*y['c']

# %%
y
# Out:
#     a   b   c   d    e
# 1   0   1   2   3    0
# 2   4   5   6   7   24
# 3   8   9  10  11   80
# 4  12  13  14  15  168
# 5  16  17  18  19  288
# 6  20  21  22  23  440

# %%
y['f']=y['a']*2

# %%
y
# Out:
#     a   b   c   d    e   f
# 1   0   1   2   3    0   0
# 2   4   5   6   7   24   8
# 3   8   9  10  11   80  16
# 4  12  13  14  15  168  24
# 5  16  17  18  19  288  32
# 6  20  21  22  23  440  40

# %%
y.shape
# Out:
# (6, 6)

# %%
y['g']=np.sin(y['a'])

# %%
y
# Out:
#     a   b   c   d    e   f         g
# 1   0   1   2   3    0   0  0.000000
# 2   4   5   6   7   24   8 -0.756802
# 3   8   9  10  11   80  16  0.989358
# 4  12  13  14  15  168  24 -0.536573
# 5  16  17  18  19  288  32 -0.287903
# 6  20  21  22  23  440  40  0.912945
